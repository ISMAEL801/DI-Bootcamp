# %% [markdown]
# # Exercises XP: Guided Student Notebook
#
# This guided notebook follows the **content on the platform**. Some cells are **prefilled** and must be **executed only**. Cells marked **To-Do** require your action. When a written answer is required, the **To-Do** appears inside a markdown cell. When code is required, the **To-Do** appears inside a code cell as comments.
#
# **Learning points** appear when a concept is important for intuition or to help you learn new tricks/concepts related to other AI topics.

# %% [markdown]
# ## Objectives
#
# **What you will learn**
# - The fundamentals of deep learning and neural networks.
# - How to build and train simple neural networks using TensorFlow or Keras.
# - The concepts of forward and backward propagation.
# - How to visualize and interpret model predictions.
#
# **What you will create**
# - A simple perceptron-based decision system.
# - A neural network for classifying handwritten digits from the MNIST dataset.
# - A forward propagation calculation for predicting house prices.
# - A Python implementation of forward and backward propagation.
# - Visualizations of predictions made by a neural network on the MNIST dataset.

# %% [markdown]
# ## 🌟 Exercise 1: Small Quiz
#
# **As stated in the instructions**
# - What is the key difference between traditional machine learning and deep learning?
# - How do artificial neural networks mimic the human brain?
# - Why does deep learning perform better on large datasets compared to traditional machine learning?
# - What are some challenges of deep learning, and how can they be addressed?
# - What is feature engineering, and why is it not needed in deep learning?
# - What role do hidden layers play in a deep learning model?
# - In an artificial neural network, what is the function of an activation function?
#
# **Guidance**
# Answer in full sentences. Use concise definitions first, then add one concrete example for any two questions to demonstrate understanding.
#
# **To-Do:** Write your answers below.

# %% [markdown]
# ##REPONSE
#
# 1. Quelle est la principale différence entre l’apprentissage automatique traditionnel et l’apprentissage profond ?
#
# L’apprentissage automatique traditionnel nécessite souvent que les humains choisissent ou créent manuellement les caractéristiques importantes avant d’entraîner le modèle. L’apprentissage profond utilise des réseaux de neurones avec plusieurs couches capables d’apprendre automatiquement des caractéristiques utiles à partir des données brutes.
#
# 2. Comment les réseaux de neurones artificiels imitent-ils le cerveau humain ?
#
# Les réseaux de neurones artificiels imitent le cerveau humain de manière simplifiée. Ils utilisent des neurones artificiels connectés entre eux. Chaque neurone reçoit des entrées, applique des poids, ajoute un biais, utilise une fonction d’activation, puis envoie une sortie à la couche suivante.
#
# 3. Pourquoi l’apprentissage profond est-il plus performant sur de grands ensembles de données que l’apprentissage automatique traditionnel ?
#
# Les modèles d’apprentissage profond possèdent de nombreux paramètres et plusieurs couches cachées. Avec une grande quantité de données, ils peuvent apprendre des modèles complexes mieux que beaucoup de modèles d’apprentissage automatique traditionnels. Par exemple, dans la reconnaissance d’images, l’apprentissage profond peut apprendre automatiquement les contours, les formes et les parties d’objets.
#
# 4. Quels sont les défis de l’apprentissage profond, et comment peut-on les résoudre ?
#
# L’apprentissage profond nécessite beaucoup de données, une grande puissance de calcul et du temps pour l’entraînement. Il peut aussi faire du surapprentissage si le modèle apprend trop bien les données d’entraînement. Ces problèmes peuvent être réduits avec plus de données, l’augmentation des données, la régularisation, le dropout, l’arrêt anticipé et l’utilisation de GPU.
#
# 5. Qu’est-ce que l’ingénierie des caractéristiques, et pourquoi est-elle moins nécessaire en apprentissage profond ?
#
# L’ingénierie des caractéristiques consiste à créer manuellement des variables d’entrée utiles pour un modèle. En apprentissage profond, elle est moins nécessaire parce que les couches cachées peuvent apprendre automatiquement les caractéristiques importantes à partir des données brutes.
#
# 6. Quel rôle jouent les couches cachées dans un modèle d’apprentissage profond ?
#
# Les couches cachées transforment les données d’entrée étape par étape. Les premières couches peuvent apprendre des modèles simples, tandis que les couches plus profondes peuvent apprendre des modèles plus complexes. Elles aident le modèle à comprendre les relations non linéaires.
#
# 7. Dans un réseau de neurones artificiel, quelle est la fonction d’une fonction d’activation ?
#
# Une fonction d’activation décide quel signal un neurone envoie à la couche suivante. Elle ajoute aussi de la non-linéarité, ce qui permet au réseau neuronal d’apprendre des modèles complexes. Des exemples de fonctions d’activation sont ReLU, sigmoid et softmax.

# %% [markdown]
# ## 🌟 Exercise 2: Building a Simple Perceptron Decision System
#
# **As stated in the instructions**
# You will create a perceptron-based decision system to decide whether you should go outside based on two inputs:
# - Temperature in °F
# - Rainy where Yes is 1 and No is 0
#
# Given parameters: Temperature weight 0.6, Rain weight 0.4, Bias 2. Compute the weighted sum
# \[ \text{Weighted Sum} = 0.6\cdot \text{Temperature} + 0.4\cdot \text{Rain} + \text{Bias} \]
# Apply a step activation:
# - If Weighted Sum > 20, output 1
# - If Weighted Sum \le 20, output 0
#
# Evaluate:
# Case 1: Temperature 70°F, Rain 0
# Case 2: Temperature 50°F, Rain 1
#
# **Guidance**
# Implement the weighted sum function yourself. Use a reusable step activation. Then compute the two cases and print the decision for each.
#
# **Learning point**
# A perceptron implements a linear decision boundary. The bias shifts the threshold. Use step activation for simple binary rules. Prefer differentiable activations when training with gradient descent.
#
# ![image.png](https://github.com/user-attachments/assets/3c4f3261-164d-4039-8e1c-aff2db7162dd)

# %%
from typing import Tuple

W_TEMP = 0.6
W_RAIN = 0.4
BIAS = 2.0

def step_activation(s: float, threshold: float = 20.0) -> int:
    return 1 if s > threshold else 0

def weighted_sum(temperature_f: float, rain01: int) -> float:
    return (W_TEMP * temperature_f) + (W_RAIN * rain01) + BIAS

case1 = (70, 0)
case2 = (50, 1)

s1 = weighted_sum(*case1)
s2 = weighted_sum(*case2)

y1 = step_activation(s1)
y2 = step_activation(s2)

print("Cas 1 : Température = 70°F, Pluie = 0")
print("Somme pondérée :", s1)
print("Décision :", y1, "=> Oui, sortir" if y1 == 1 else "=> Non, rester à l'intérieur")

print("\nCas 2 : Température = 50°F, Pluie = 1")
print("Somme pondérée :", s2)
print("Décision :", y2, "=> Oui, sortir" if y2 == 1 else "=> Non, rester à l'intérieur")
# Out:
# Cas 1 : Température = 70°F, Pluie = 0
# Somme pondérée : 44.0
# Décision : 1 => Oui, sortir
#
# Cas 2 : Température = 50°F, Pluie = 1
# Somme pondérée : 32.4
# Décision : 1 => Oui, sortir

# %% [markdown]
# Pour le cas 1, la somme pondérée est :
#
# (70 × 0,6) + (0 × 0,4) + 2 = 44
#
# Comme 44 est supérieur à 20, le perceptron donne une sortie de 1. Donc la décision est : Oui, sortir.
#
# Pour le cas 2, la somme pondérée est :
#
# (50 × 0,6) + (1 × 0,4) + 2 = 32,4
#
# Comme 32,4 est aussi supérieur à 20, le perceptron donne une sortie de 1. Donc la décision est également : Oui, sortir.
#
# Le perceptron a suggéré de sortir dans les deux cas parce que les deux sommes pondérées sont supérieures au seuil de 20.

# %% [markdown]
# ## 🌟 Exercise 3: Building a Simple Neural Network with TensorFlow or Keras
#
# **As stated in the instructions**
# Build a classifier for MNIST with:
# - One input layer
# - One hidden layer with 128 neurons and ReLU activation
# - One output layer with 10 neurons and softmax activation
#
# Steps:
# 1. Import TensorFlow and needed modules from `tensorflow.keras`
# 2. Load the MNIST dataset
# 3. Normalize data by dividing by 255.0
# 4. One-hot encode the labels
# 5. Build a sequential model with Flatten, Dense(128, ReLU), Dense(10, softmax)
# 6. Compile with optimizer `adam`, loss `categorical_crossentropy`, metrics `accuracy`
# 7. Train and evaluate on the test set
#
# **Guidance**
# You will execute prefilled boilerplate for imports and dataset loading. You will complete the one-hot encoding and the model specification, compile, train, and evaluate.
#
# **Learning point**
# Normalization stabilizes optimization. One-hot encoding matches softmax outputs to target vectors. ReLU accelerates training by avoiding saturation, while softmax maps logits to a probability simplex.
#
# ![image.png](https://github.com/user-attachments/assets/61737b80-69cb-41a1-aea5-76092cd2a373)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

print("TensorFlow:", tf.__version__)

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)

y_train_oh = to_categorical(y_train, num_classes=10)
y_test_oh = to_categorical(y_test, num_classes=10)

print("Labels one-hot:", y_train_oh.shape, y_test_oh.shape)

model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation="relu"),
    layers.Dense(10, activation="softmax"),
])

model.summary()

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    x_train,
    y_train_oh,
    epochs=5,
    batch_size=32,
    validation_split=0.1
)

# Évaluer le modèle
test_loss, test_acc = model.evaluate(x_test, y_test_oh)

print("Résultat sur les données de test :")
print("Test loss :", float(test_loss))
print("Test accuracy :", float(test_acc))
# Out:
# TensorFlow: 2.20.0
# Train shape: (60000, 28, 28)
# Test shape: (10000, 28, 28)
# Labels one-hot: (60000, 10) (10000, 10)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9208 - loss: 0.2735 - val_accuracy: 0.9645 - val_loss: 0.1321
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9643 - loss: 0.1212 - val_accuracy: 0.9722 - val_loss: 0.0920
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9741 - loss: 0.0842 - val_accuracy: 0.9762 - val_loss: 0.0873
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9801 - loss: 0.0641 - val_accuracy: 0.9753 - val_loss: 0.0823
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9846 - loss: 0.0493 - val_accuracy: 0.9778 - val_loss: 0.0838
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9734 - loss: 0.0851
# Résultat sur les données de test :
# Test loss : 0.08512691408395767
# Test accuracy : 0.9733999967575073

# %% [markdown]
# ## 🌟 Exercise 4: Forward Propagation Calculation
#
# **As stated in the instructions**
# Predict house prices given:
# - Inputs: x₁ = 2000 square feet, x₂ = 3 bedrooms
# - Weights: w₁ = 0.5, w₂ = 0.7
# - Bias: b = 50,000
# - Activation: ReLU
#
# Compute z before activation, apply ReLU, and interpret the prediction.
#
# **Guidance**
# Write scalar computations. Then reason about the role of the bias and ReLU on the output scale.
#
# **Learning point**
# ReLU passes positive linear combinations unchanged and zeros out negatives. Bias sets the baseline prediction independent of inputs.
# ![](./figs/1.gif)

# %%
x1, x2 = 2000.0, 3.0
w1, w2 = 0.5, 0.7
b = 50000.0

z = x1 * w1 + x2 * w2 + b

y = max(0, z)

print("Valeur avant activation z :", z)
print("Prédiction après ReLU :", y)
# Out:
# Valeur avant activation z : 51002.1
# Prédiction après ReLU : 51002.1

# %% [markdown]
# ##INTERPRETATION
# La valeur avant activation est :
#
# z = (2000 × 0,5) + (3 × 0,7) + 50000 = 51002,1
#
# La fonction d’activation ReLU garde les valeurs positives inchangées :
#
# ReLU(51002,1) = 51002,1
#
# Donc le prix prédit de la maison est de 51 002,1.
#
# Le biais a une très forte influence parce qu’il ajoute 50 000 à la prédiction.

# %% [markdown]
# ## 🌟 Exercise 5 (optional): Implementing Forward and Backward Propagation in Python
#
# **As stated in the enoncé**
# You will code a simple neural network that performs forward propagation and backpropagation for a regression problem predicting exam scores from study hours.
#
# **Guidance**
# Run the prefilled code. Then modify the learning rate or initial weights and observe changes in the loss and updates.
# Provide a short written explanation.
#
# **Learning point**
# Gradient descent updates parameters in the direction of steepest loss reduction.
# The learning rate controls step size. Too small slows learning. Too large risks divergence.

# %%
import numpy as np

x = np.array([4, 80])
w = np.array([0.6, 0.3])
b = 10

def forward_propagation(x, w, b):
    z = np.dot(x, w) + b
    return z


y_pred = forward_propagation(x, w, b)

y_true = 85

loss = 0.5 * (y_true - y_pred) ** 2

grad_w = -(y_true - y_pred) * x
grad_b = -(y_true - y_pred)

learning_rate = 0.01

w_new = w - learning_rate * grad_w
b_new = b - learning_rate * grad_b

print("Initial Prediction:", y_pred)
print("Loss:", loss)
print("Updated Weights:", w_new)
print("Updated Bias:", b_new)
# Out:
# Initial Prediction: 36.4
# Loss: 1180.98
# Updated Weights: [ 2.544 39.18 ]
# Updated Bias: 10.486

# %% [markdown]
# ##EXPLICATION
# La descente de gradient réduit l’erreur parce qu’elle met à jour les poids et le biais dans la direction opposée au gradient.
#
# Le gradient nous indique comment la fonction de perte change lorsque chaque poids change.
#
# Si la prédiction est trop basse, la mise à jour peut augmenter les poids ou le biais.
# Si la prédiction est trop élevée, la mise à jour peut les diminuer.
#
# Dans cet exemple, la prédiction initiale est loin de la vraie note, donc la perte est élevée.
# Après le calcul des gradients, les poids et le biais sont mis à jour afin de rapprocher la prédiction de la vraie valeur.
#
# Le taux d’apprentissage contrôle la taille de la mise à jour.
# Si le taux d’apprentissage est trop petit, l’apprentissage est lent.
# S’il est trop grand, le modèle peut dépasser la bonne solution et la perte peut augmenter.

# %% [markdown]
# ## 🌟 Exercise 6 (optional): Visualizing Predictions on MNIST
#
# **As stated in the enoncé**
# Train a simple model on MNIST, then visualize predictions for some test images with predicted labels.
#
# **Guidance**
# Reuse the model from Exercise 3 if still in memory. Otherwise re-run Exercise 3. Plot a grid of test images with predicted labels and optionally true labels.
#
# **Learning point**
# Softmax outputs are probabilities over classes. Inspect the confidence values. Visual errors often indicate confusions between similar digits.
#
# ![image.png](https://github.com/user-attachments/assets/e00d3913-55d4-4b62-8f70-1216bcc2e4e4)

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 12

np.random.seed(42)
idx = np.random.choice(len(x_test), size=N, replace=False)

x_vis = x_test[idx]
y_true = y_test[idx]

y_prob = model.predict(x_vis)
y_pred = np.argmax(y_prob, axis=1)

cols = 6
rows = int(np.ceil(len(idx) / cols))

plt.figure(figsize=(12, 2 * rows))

for i, k in enumerate(idx, 1):
    plt.subplot(rows, cols, i)
    plt.imshow(x_test[k], cmap="gray")
    plt.title(f"pred={y_pred[i-1]} true={y_true[i-1]}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
