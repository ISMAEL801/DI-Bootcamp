# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# ### Your answer
# > To-Do:
# Please write your full answer below using complete sentences and clear structure.

# %% [markdown]
# ###REPONSE

# %% [markdown]
# ## 1. Énoncé du problème
#
# L’objectif de ce projet est de développer un modèle capable de prédire si un demandeur de prêt risque de faire défaut de paiement ou non. La variable cible sera donc le **statut de remboursement du prêt**, par exemple `défaut de paiement = oui/non`. Cette prédiction permettra aux institutions financières de mieux évaluer le risque avant d’accorder un prêt, de fixer des conditions adaptées et de réduire les pertes liées aux mauvais remboursements.
#
# En d’autres termes, le problème consiste à utiliser les informations disponibles sur un client et sur son prêt afin d’estimer la probabilité qu’il ne rembourse pas correctement son crédit.
#
# ## 2. Types de données nécessaires
#
# Pour construire un modèle de prédiction fiable, plusieurs types de données seraient nécessaires.
#
# Tout d’abord, il faudrait collecter les **informations personnelles du demandeur**, comme l’âge, la situation matrimoniale, le niveau d’éducation, la profession et le lieu de résidence. Ces données peuvent aider à comprendre le profil général du client et à détecter certains facteurs pouvant influencer sa capacité de remboursement.
#
# Ensuite, il serait important de collecter les **informations financières du demandeur**, comme le revenu mensuel, les charges mensuelles, le niveau d’endettement, l’épargne disponible et la stabilité de l’emploi. Ces informations sont essentielles, car une personne avec un revenu faible ou des charges élevées peut présenter un risque de défaut plus important.
#
# Il faudrait également collecter les **données liées au crédit**, comme le montant du prêt demandé, la durée du prêt, le taux d’intérêt, le type de prêt et le montant des mensualités. Ces données permettent d’évaluer si le prêt demandé est raisonnable par rapport à la capacité financière du demandeur.
#
# Les **scores de crédit** sont aussi très importants. Ils donnent une indication sur la fiabilité financière du client. Un score de crédit élevé montre généralement que le client a un bon historique de remboursement, tandis qu’un score faible peut indiquer un risque plus élevé.
#
# Il serait aussi nécessaire d’utiliser l’**historique de remboursement** du client, par exemple les anciens prêts, les retards de paiement, les défauts passés, les pénalités et les crédits déjà remboursés. Ce type de données est très utile, car le comportement passé d’un client peut aider à prédire son comportement futur.
#
# Enfin, il serait utile de collecter des **données économiques externes**, comme le taux de chômage, l’inflation, le secteur d’activité du client ou les conditions économiques générales. Ces données peuvent influencer la capacité de remboursement, surtout si le client travaille dans un secteur instable.
#
# ## 3. Sources possibles de données
#
# Les données peuvent être collectées auprès de plusieurs sources réalistes.
#
# La première source serait les **dossiers internes des institutions financières**. Les banques et les organismes de crédit possèdent déjà des informations sur les demandes de prêt, les montants accordés, les remboursements effectués et les défauts de paiement. Ces données peuvent être extraites des systèmes internes de gestion des prêts.
#
# Une autre source importante serait les **agences d’évaluation du crédit**. Ces agences fournissent des scores de crédit et des historiques financiers permettant d’évaluer la fiabilité d’un emprunteur. L’intégration de ces données peut se faire à travers des partenariats ou des API sécurisées.
#
# Les **formulaires de demande de prêt** constituent également une source directe de données. Lorsqu’un client demande un prêt, il fournit des informations personnelles, professionnelles et financières. Ces informations peuvent être collectées de manière structurée dans une base de données.
#
# Les **relevés bancaires et historiques de transactions** peuvent aussi être utilisés, avec l’accord du client. Ils permettent d’analyser les revenus réels, les dépenses, les habitudes financières et la régularité des entrées d’argent.
#
# Enfin, les **sources publiques ou économiques** peuvent compléter l’analyse. Par exemple, les données sur le chômage, l’inflation ou les tendances économiques peuvent être obtenues auprès d’institutions publiques, de banques centrales ou d’organismes statistiques.
#
# ## 4. Risques et contraintes
#
# Ce projet présente plusieurs risques et contraintes. Le premier risque concerne la **confidentialité des données**. Les données financières et personnelles sont sensibles et doivent être protégées. Il faut donc respecter les règles de protection des données, obtenir le consentement des clients et sécuriser les bases de données.
#
# Il existe aussi des contraintes liées à la **réglementation**. Les institutions financières doivent respecter les lois en vigueur concernant l’utilisation des données, la lutte contre la discrimination et la transparence des décisions automatisées.
#
# La **qualité des données** est également un point important. Si les données sont incomplètes, incorrectes ou mal mises à jour, le modèle peut produire de mauvaises prédictions. Il faudra donc nettoyer les données, traiter les valeurs manquantes et vérifier leur cohérence.
#
# Un autre risque important est le **biais d’échantillonnage**. Si les données historiques contiennent des décisions injustes ou déséquilibrées, le modèle peut reproduire ces biais. Par exemple, certains groupes de clients pourraient être injustement classés comme plus risqués. Il faudra donc analyser les biais possibles et mettre en place des contrôles.
#
# Enfin, il faut prévoir une bonne **gouvernance des données**. Cela signifie définir qui peut accéder aux données, comment elles sont utilisées, comment elles sont mises à jour et comment les décisions du modèle sont contrôlées. Une bonne gouvernance permet de rendre le projet plus fiable, plus transparent et plus responsable.
#
# ## Conclusion
#
# La prédiction des défauts de paiement de prêts est un projet important pour les institutions financières. Elle permet de mieux évaluer les risques, de prendre de meilleures décisions d’octroi de crédit et de réduire les pertes financières. Pour réussir ce projet, il faut collecter des données personnelles, financières, historiques et économiques fiables. Il est également nécessaire de respecter la confidentialité, la réglementation, la qualité des données et l’équité du modèle.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]
df = pd.DataFrame(columns=example_columns)

# Please replace this list with the actual columns that you select.
selected_features = [
    # e.g., "credit_score","debt_to_income","annual_income","loan_amount","interest_rate",
    # "employment_length","num_delinquencies","total_utilization"
]

print("You will now justify the selected features in complete sentences below.")

# %% [markdown]
# ### Your justification
# > To-Do: Please write complete sentences that justify the relevance of each selected feature.
# If you excluded any common features, please state your reasons in complete sentences.
#
# Also explain, in two complete sentences, how you would encode categorical variables and how you would impute missing values.

# %% [markdown]
# ###REPONSE

# %%
import pandas as pd

example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]

df = pd.DataFrame(columns=example_columns)

selected_features = [
    "credit_score",
    "debt_to_income",
    "annual_income",
    "loan_amount",
    "interest_rate",
    "employment_length",
    "num_delinquencies",
    "total_utilization",
    "term",
    "home_ownership",
    "purpose"
]

print("Selected features:")
print(selected_features)

print("\nYou will now justify the selected features in complete sentences below.")

# %% [markdown]
# # Justification des caractéristiques sélectionnées
#
# Pour prédire les défauts de paiement de prêts, les caractéristiques les plus pertinentes sont `credit_score`, `debt_to_income`, `annual_income`, `loan_amount`, `interest_rate`, `employment_length`, `num_delinquencies`, `total_utilization`, `term`, `home_ownership` et `purpose`.
#
# La variable `credit_score` est très importante, car elle représente le niveau de fiabilité financière du demandeur. Un score de crédit faible peut indiquer un risque plus élevé de défaut de paiement, tandis qu’un score élevé montre généralement un meilleur historique de remboursement.
#
# La variable `debt_to_income` est pertinente, car elle mesure le rapport entre les dettes du demandeur et ses revenus. Si ce ratio est élevé, cela signifie que le demandeur utilise déjà une grande partie de ses revenus pour rembourser des dettes, ce qui peut augmenter le risque de défaut.
#
# La variable `annual_income` est importante, car elle permet d’évaluer la capacité financière globale du demandeur. Un revenu annuel plus élevé peut faciliter le remboursement du prêt, alors qu’un revenu faible peut rendre les mensualités plus difficiles à supporter.
#
# La variable `loan_amount` est pertinente, car le montant du prêt influence directement la charge de remboursement. Un prêt très élevé peut augmenter le risque de défaut si le revenu du demandeur n’est pas suffisant.
#
# La variable `interest_rate` est également importante, car un taux d’intérêt élevé augmente le coût total du prêt. Plus le taux est élevé, plus les mensualités peuvent être lourdes, ce qui peut accroître la probabilité de non-remboursement.
#
# La variable `employment_length` est utile, car elle indique la stabilité professionnelle du demandeur. Une personne ayant une longue durée d’emploi peut être considérée comme plus stable financièrement qu’une personne avec un emploi récent ou instable.
#
# La variable `num_delinquencies` est très pertinente, car elle indique le nombre de retards ou incidents de paiement passés. Un demandeur ayant déjà eu plusieurs retards de paiement peut présenter un risque plus élevé de défaut futur.
#
# La variable `total_utilization` est importante, car elle montre le niveau d’utilisation du crédit disponible. Une utilisation élevée du crédit peut indiquer une dépendance excessive à l’endettement et donc un risque plus important.
#
# La variable `term` est pertinente, car la durée du prêt influence le montant des mensualités et le risque dans le temps. Un prêt plus long peut être plus risqué, car la situation financière du demandeur peut changer pendant la période de remboursement.
#
# La variable `home_ownership` peut aider à évaluer la stabilité financière du demandeur. Par exemple, une personne propriétaire peut avoir une situation patrimoniale différente d’une personne locataire.
#
# La variable `purpose` est utile, car l’objectif du prêt peut influencer le risque. Un prêt utilisé pour consolider des dettes, par exemple, peut avoir un profil de risque différent d’un prêt destiné à un achat personnel ou professionnel.
#
# Certaines variables peuvent être exclues du modèle. La variable `zip_code` peut être exclue, car elle est trop précise géographiquement et peut introduire des biais liés à la localisation. La variable `state` peut aussi être utilisée avec prudence, car elle peut refléter des différences économiques régionales, mais elle peut également introduire des biais géographiques si elle est mal interprétée. La variable `num_open_accounts` peut être moins importante seule, car elle ne montre pas directement si le client rembourse bien ses dettes ; elle devient plus utile lorsqu’elle est combinée avec d’autres informations comme l’utilisation totale du crédit.
#
# Pour encoder les variables catégorielles comme `home_ownership`, `purpose`, `term` et `application_type`, j’utiliserais l’encodage one-hot afin de transformer chaque catégorie en colonne numérique. Pour les valeurs manquantes, j’imputerais les variables numériques avec la médiane et les variables catégorielles avec la modalité la plus fréquente ou une catégorie `Unknown` lorsque l’information manquante peut elle-même être significative.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))

# %% [markdown]
# ### Your answer
# > To-Do: Please write complete sentences that explain your model choice, your evaluation plan, your approach to class imbalance, and your threshold selection strategy.

# %% [markdown]
# ###REPONSE

# %% [markdown]
# Pour une prédiction de défaut de paiement de prêt, je choisirais des modèles de **classification**, car la variable cible est binaire : le client fait défaut ou ne fait pas défaut. D’après le schéma des algorithmes scikit-learn, les modèles adaptés à ce type de problème sont par exemple la **régression logistique**, le **Random Forest**, le **SVM**, le **K-Nearest Neighbors** et le **Naive Bayes**.
#
# Je choisirais d’abord la **régression logistique** comme modèle de base. Ce modèle est adapté parce qu’il fonctionne bien pour les problèmes de classification binaire et il est facile à interpréter. Dans un contexte bancaire, l’interprétation est importante, car il faut pouvoir expliquer pourquoi un client est considéré comme risqué.
#
# Je choisirais ensuite un modèle plus puissant comme le **Random Forest Classifier**. Ce modèle est utile parce qu’il peut capturer des relations complexes entre les variables, par exemple entre le revenu, le score de crédit, le taux d’endettement, le montant du prêt et l’historique de remboursement. Il est aussi souvent performant lorsque les données contiennent plusieurs caractéristiques numériques et catégorielles.
#
# Je pourrais également tester un **SVM Classifier** si le nombre de données n’est pas trop grand. Le SVM peut être efficace pour séparer deux classes lorsque la frontière entre les clients risqués et non risqués est complexe. Cependant, il peut être plus coûteux en temps de calcul sur de très grands datasets.
#
# Pour évaluer la performance du modèle, je diviserais les données en deux parties : un ensemble d’entraînement et un ensemble de test. Par exemple, j’utiliserais 80 % des données pour entraîner le modèle et 20 % pour le tester. Cette séparation permet de vérifier si le modèle fonctionne bien sur de nouvelles données.
#
# J’utiliserais aussi une validation croisée stratifiée, par exemple une validation croisée à 5 plis. La stratification est importante parce qu’elle garde la même proportion de clients en défaut et non en défaut dans chaque partie des données. Cela permet d’obtenir une évaluation plus fiable, surtout lorsque la classe des défauts de paiement est minoritaire.
#
# Les indicateurs de performance que je communiquerais sont l’accuracy, la précision, le rappel, le F1-score, le ROC-AUC, le PR-AUC et la matrice de confusion. L’accuracy indique le pourcentage global de bonnes prédictions, mais elle peut être trompeuse si les classes sont déséquilibrées. La précision indique parmi les clients prédits comme risqués, combien le sont réellement. Le rappel indique parmi les vrais clients en défaut, combien ont été correctement détectés. Le F1-score permet d’équilibrer la précision et le rappel. Le ROC-AUC mesure la capacité du modèle à distinguer les clients risqués des clients non risqués. Le PR-AUC est très utile lorsque la classe “défaut de paiement” est minoritaire.
#
# La matrice de confusion est importante parce qu’elle permet de voir les vrais positifs, les vrais négatifs, les faux positifs et les faux négatifs. Dans ce contexte, un faux négatif est dangereux, car cela signifie qu’un client qui risque de faire défaut est classé comme non risqué. Un faux positif peut aussi poser problème, car cela peut conduire à refuser un prêt à un client capable de rembourser.
#
# Le seuil de décision ne doit pas forcément rester à 0,5. Je choisirais le seuil en fonction du coût métier des erreurs. Si la banque veut éviter au maximum les pertes liées aux défauts de paiement, je choisirais un seuil plus bas afin d’augmenter le rappel et détecter plus de clients risqués. Si la banque veut éviter de refuser trop de bons clients, je choisirais un seuil plus élevé afin d’améliorer la précision.
#
# Pour traiter le déséquilibre des classes, j’utiliserais d’abord une séparation stratifiée des données. Ensuite, je pourrais utiliser la pondération des classes, par exemple `class_weight="balanced"`, pour donner plus d’importance à la classe minoritaire. Si le déséquilibre est très fort, je pourrais aussi utiliser des techniques de rééchantillonnage, comme le suréchantillonnage des clients en défaut ou le sous-échantillonnage des clients non risqués.
#
# Pour optimiser le modèle, je testerais plusieurs hyperparamètres avec `GridSearchCV` ou `RandomizedSearchCV`. Par exemple, pour un Random Forest, je pourrais tester le nombre d’arbres, la profondeur maximale des arbres et le nombre minimum d’échantillons par feuille. Pour éviter les fuites de données, l’imputation, l’encodage, la normalisation et la sélection des caractéristiques doivent être faits dans un pipeline et uniquement à partir des données d’entraînement pendant la validation croisée.
#
# En conclusion, je commencerais avec une régression logistique pour avoir un modèle simple et interprétable, puis je comparerais ses résultats avec des modèles plus avancés comme Random Forest, SVM ou Gradient Boosting. Le meilleur modèle serait choisi en fonction des métriques les plus adaptées au problème, surtout le rappel, le F1-score, le PR-AUC et la matrice de confusion, car l’objectif principal est de bien détecter les clients susceptibles de faire défaut.

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below, using full sentences for each scenario.

# %% [markdown]
# ###REPONSE

# %% [markdown]
# ## 1. Prédiction des cours boursiers
#
# Pour la prédiction des cours boursiers, le type d’apprentissage automatique le plus approprié est l’**apprentissage supervisé**, plus précisément un problème de **régression**. Ce choix est adapté parce que l’objectif est de prédire une valeur numérique continue, par exemple le prix futur d’une action.
#
# Les données d’entrée peuvent être les anciens prix d’ouverture, de clôture, les prix les plus hauts et les plus bas, le volume des transactions, les rendements passés et éventuellement des indicateurs économiques ou techniques.
# La sortie attendue est un prix futur, par exemple le cours de clôture du lendemain ou le prix prévu pour une période donnée.
# Le signal d’apprentissage est la comparaison entre le prix prédit par le modèle et le prix réel observé dans les données historiques.
#
# ## 2. Organisation d’une bibliothèque
#
# Pour organiser une bibliothèque en regroupant les livres par genres ou catégories selon leurs similitudes, le type d’apprentissage automatique le plus approprié est l’**apprentissage non supervisé**, plus précisément le **clustering**. Ce choix est adapté parce qu’on cherche à regrouper automatiquement les livres sans forcément disposer au départ d’étiquettes précises pour chaque genre.
#
# Les données d’entrée peuvent être les titres des livres, les résumés, les mots-clés, les auteurs, les thèmes, les descriptions et les caractéristiques textuelles extraites des livres.
# La sortie attendue est un ensemble de groupes de livres similaires, par exemple un groupe de livres de science-fiction, un groupe de romans historiques ou un groupe de livres de développement personnel.
# L’objectif d’apprentissage est de trouver des similarités entre les livres afin de les regrouper de manière cohérente.
#
# ## 3. Robot qui navigue dans un labyrinthe
#
# Pour programmer un robot afin qu’il navigue et trouve le chemin le plus court dans un labyrinthe, le type d’apprentissage automatique le plus approprié est l’**apprentissage par renforcement**. Ce choix est adapté parce que le robot doit apprendre à prendre des décisions étape par étape dans un environnement, en recevant des récompenses ou des pénalités selon ses actions.
#
# Les données d’entrée peuvent être la position actuelle du robot, les obstacles autour de lui, les directions possibles et la position de l’objectif dans le labyrinthe.
# La sortie attendue est une action à effectuer, par exemple avancer, tourner à gauche, tourner à droite ou reculer.
# Le signal d’apprentissage est une récompense positive lorsque le robot se rapproche de la sortie ou trouve le chemin le plus court, et une pénalité lorsqu’il heurte un mur, prend un mauvais chemin ou met trop de temps.
#
# ## Conclusion
#
# En résumé, la prédiction des cours boursiers relève de l’apprentissage supervisé, car on utilise des données historiques avec des valeurs cibles connues. L’organisation d’une bibliothèque relève de l’apprentissage non supervisé, car il s’agit de découvrir automatiquement des groupes similaires. La navigation d’un robot dans un labyrinthe relève de l’apprentissage par renforcement, car le robot apprend à travers ses actions, ses erreurs et les récompenses reçues.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("Please explain in complete sentences when you would use the elbow method and how you would interpret it.")

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below as three paragraphs, one for supervised learning, one for unsupervised learning, and one for reinforcement learning.

# %% [markdown]
# ###REPONSE

# %% [markdown]
# Pour un modèle d’**apprentissage supervisé**, je choisirais un modèle de classification comme **KNeighbors Classifier**, **SVC**, **Linear SVC**, **Naive Bayes** ou **SGD Classifier**, car ces modèles apparaissent dans la partie classification du schéma scikit-learn. Ces modèles sont adaptés lorsque l’objectif est de prédire une catégorie, par exemple si un client fera défaut de paiement ou non. Pour évaluer ce modèle, je commencerais par diviser les données en un ensemble d’entraînement et un ensemble de test, par exemple 80 % pour l’entraînement et 20 % pour le test. J’utiliserais aussi une validation croisée, par exemple une validation croisée à 5 plis, afin de vérifier si le modèle garde de bonnes performances sur plusieurs parties différentes du dataset. Les indicateurs que je communiquerais sont l’exactitude, la précision, le rappel, le score F1, le ROC-AUC et le PR-AUC. L’exactitude permet de mesurer le pourcentage global de bonnes prédictions, mais elle peut être trompeuse si les classes sont déséquilibrées. La précision indique parmi les prédictions positives combien sont réellement correctes, tandis que le rappel indique combien de vrais cas positifs ont été retrouvés par le modèle. Le score F1 permet d’équilibrer la précision et le rappel. Le ROC-AUC permet d’évaluer la capacité du modèle à distinguer les classes, et le PR-AUC est utile lorsque la classe positive est rare. Un défi majeur de l’évaluation d’un modèle supervisé est que les résultats peuvent être biaisés si les classes sont déséquilibrées ou si le jeu de test n’est pas représentatif.
#
# Pour un modèle d’**apprentissage non supervisé**, je choisirais un modèle de clustering comme **KMeans**, **MiniBatch KMeans**, **MeanShift**, **VBGMM** ou **Spectral Clustering**, car ces modèles apparaissent dans la partie clustering du schéma. Ce type de modèle est adapté lorsqu’on veut regrouper automatiquement des données sans variable cible connue. Par exemple, on peut regrouper des clients, des livres ou des produits selon leurs ressemblances. Pour évaluer l’efficacité du clustering, j’utiliserais le **score de silhouette**, qui permet de mesurer si les points sont proches des éléments de leur propre groupe et éloignés des autres groupes. Un score de silhouette élevé indique généralement que les clusters sont bien séparés. J’utiliserais aussi la **méthode du coude** pour choisir le bon nombre de clusters avec KMeans. Cette méthode consiste à tester plusieurs valeurs de `k` et à observer le moment où la diminution de l’inertie devient moins importante. Je pourrais aussi utiliser des graphiques de diagnostic, comme un nuage de points après réduction de dimension avec PCA, pour visualiser si les groupes semblent bien formés. Un défi majeur de l’évaluation d’un modèle non supervisé est qu’il n’y a pas toujours de bonne réponse connue pour confirmer que les groupes trouvés sont réellement corrects.
#
# Pour un modèle d’**apprentissage par renforcement**, je choisirais un agent qui apprend à prendre des décisions dans un environnement, par exemple un robot qui doit trouver le chemin le plus court dans un labyrinthe. Ce type d’apprentissage n’est pas directement représenté dans les parties classification, régression, clustering ou réduction de dimension du schéma, mais il correspond à une situation où un agent apprend grâce aux récompenses et aux pénalités. Pour mesurer le succès du modèle, je suivrais la récompense cumulative obtenue par l’agent au fil des épisodes. Si la récompense cumulative augmente avec le temps, cela signifie que l’agent apprend à prendre de meilleures décisions. J’observerais aussi la convergence, c’est-à-dire le moment où les performances deviennent stables. Il faudrait également contrôler l’équilibre entre exploration et exploitation. Au début, l’agent doit explorer plusieurs actions pour découvrir les meilleures stratégies, puis il doit progressivement exploiter les actions qui donnent les meilleures récompenses. Un défi majeur de l’évaluation d’un modèle d’apprentissage par renforcement est que les résultats peuvent varier selon l’environnement, le nombre d’épisodes et la stratégie d’exploration utilisée.
